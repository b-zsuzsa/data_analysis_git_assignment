# %% [markdown]
# # Data Visualization Assignment – Data Analysis Course
# **Welcome** to the Data Visualization assignment. Your task is to explore a dataset of your choice and create meaningful visual representations of the data. Use Python or any other data analysis tool (e.g., Flourish) to generate at least six visualizations, incorporating at least four different types, to effectively communicate insights and trends.
#
# **Exploration and Tools**
# Explore the following links to experiment with various visualization tools and explore different types of visualizations:
#
# [RAWGraphs](https://www.rawgraphs.io/)
# [Flourish](https://flourish.studio/)
# [Data Visualization Catalogue](https://datavizcatalogue.com/)
#
# You can create visualizations using Python (ex. Matplotlib) or any other data analysis tool of your choice (e.g., Flourish or other preferred platforms).
#
#
# **Task Description**
# Find a dataset from [Kaggle](https://www.kaggle.com/) or another source and create at least **six** different visualizations.
#
#
# *   Use a minimum of four different visualization types (refer to Data Visualization Catalogue for options).
#
# *   The visualizations should be coherent and build a story about the data.
#
# **Figure Descriptions**
# For each figure, provide a short descriptive text, similar to what you would include in a scientific paper.
#
# **Submission Instructions**
# Your solution should be uploaded to Git, using the same GitHub project as your last assignment.
# Add your solution (code + data) to the project.
# If the dataset is too large, provide a link to the data in your notebook instead.
# Commit and push your work to your branch, ensuring it is visible.
#
# Put your visualisations down below (if you choose python).

# %%
from IPython.display import Image

# %% [markdown]
# Data source: Starbucks Beverage Components (https://www.kaggle.com/datasets/henryshan/starbucks?resource=download)

# %% [markdown]
# ## Flourish - Filtering Data by Categories
# The beverages were filtered by beverage preparation method and beverage category, to make comparison easier. The original graphs are interactive in HTML form.

# %% [markdown]
# ### Column chart
# Different beverage preparation methods: Short, tall, grande, venti, short, nonfat milk, 2% milk, soymilk, tall nonfat milk, grande nonfat milk, venti nonfat milk, solo, doppio, whole milk.

# %%
Image("calories.png")

# %% [markdown]
# **“From Light to Loaded: The Caloric Spectrum of Short Starbucks Beverages!”** 🍵➡️🍫
#
# Caloric content of Starbucks beverages (short size). The x-axis represents different beverages available in the short size, while the y-axis shows the corresponding calorie content. Among the analyzed drinks, the short cappuccino has the lowest caloric value, whereas the short white chocolate mocha (without whipped cream) contains more than three times as many calories. This variation highlights the impact of ingredient composition on energy intake, even within the same portion size.
#
# *A tiny Cappuccino keeps it light, while a Short White Chocolate Mocha (no whip) packs over 3x the calories! Choose wisely!*

# %%
Image("milk_vs_soymilk.png")

# %% [markdown]
# **"Soy Wins the Calorie Battle! 🥛 vs. 🌱"**
#
# Caloric comparison of Classic Espresso Drinks made with 2% milk and soymilk. The two column charts illustrate the calorie content (y-axis) of beverages (x-axis) prepared with different milk options. Across all drinks, those made with soymilk consistently contain fewer calories than their 2% milk counterparts. This finding underscores the impact of milk choice on total caloric intake in espresso-based beverages.
#
# *Switching to soymilk isn’t just a trend—it’s a lower-calorie choice across all Classic Espresso Drinks!*

# %% [markdown]
# ### Donut chart

# %%
Image("C-vitamin_smoothies.png")

# %% [markdown]
# **A Vitamin C Knockout: 🍓🥊 vs. 🍫🍌"**
#
# Vitamin C content (% Daily Value) in Starbucks smoothies. This donut chart illustrates the proportion of the recommended daily intake of Vitamin C provided by different smoothie options. The Strawberry Banana Smoothie contains the highest amount, supplying 100% of the daily value, while the Banana Chocolate Smoothie provides the lowest, contributing only 15%. These variations highlight the influence of fruit composition on micronutrient content in blended beverages.
#
# *Not all smoothies are created equal! The Strawberry Banana Smoothie delivers a full 100% of your daily Vitamin C, while the Banana Chocolate Smoothie lags far behind at just 15%!*

# %% [markdown]
# ### Bar chart
# Beverage categories: coffee, classic espresso drinks, signature espresso drinks, Tazo tea drinks, shaken iced beverages, smoothies, frappuccino blended coffee, frappuccino light blended coffee, frappuccino blended creme

# %%
Image("calories_by_category.png")

# %% [markdown]
# **"From Barely There to Calorie Beware! ☕🔥"**
#
# Caloric content of Starbucks beverages in the Coffee category. The bar chart displays the calorie content (x-axis) of different coffee beverages (y-axis). Espresso has the lowest calorie content, with fewer than 10 calories per serving, while the Caffè Mocha (without whipped cream) contains the highest, at almost 350 calories. This range highlights the significant variation in energy intake depending on beverage composition, particularly the addition of milk, syrups, and other ingredients.
#
# *A simple espresso keeps it light with fewer than 10 calories, but a Caffè Mocha (no whip) packs a hefty 350! Coffee choices matter!*

# %% [markdown]
# ## RAWGraphs 2.0 - Distributions and Correlations

# %% [markdown]
# ### Boxplot - Distribution of calories in different beverage categories

# %%
Image("boxplot.png")

# %% [markdown]
# **"Counting Calories: Not All Starbucks Categories Are Created Equal! ☕🥤🍫"**
#
# *From light sips to calorie-packed treats, this boxplot reveals the wide range of calories across beverage categories!*
#
# Distribution of caloric content across different Starbucks beverage categories. The boxplot represents the range, median, and variability of calorie values within each category (x-axis), with calorie content shown on the y-axis. Some categories exhibit a broad range of values, indicating diverse ingredient compositions, while others remain more consistent. This visualization highlights the disparities in caloric density between different beverage types, helping to inform choices based on energy intake considerations.

# %% [markdown]
# ### Bubble chart - correlation between the calories and amount of sugar in different beverages

# %%
Image("calories_sugar_correlation.png")

# %% [markdown]
# **"Sugar vs. Calories: A Sweet but Costly Trade-off! 🍭☕🥤"**
#
# *More sugar often means more calories—but how do different Starbucks beverage categories compare? This bubble chart spills the truth!*
#
# Relationship between sugar content and caloric value in Starbucks beverages. The bubble chart displays sugar content (x-axis) and calorie content (y-axis) for various beverage categories, with each category represented by a different color. A general upward trend suggests a correlation between higher sugar content and increased calorie values, though variability exists among different beverage types. The clustering of certain categories indicates distinct formulation patterns affecting nutritional composition.

# %% [markdown]
# Adding another dimension: the amount of coffeine - bubble size.

# %%
Image("correlation.png")

# %% [markdown]
# **"The Coffee Paradox: More Caffeine, Fewer Calories, Less Sugar! ☕💪"**
#
# *If you want a caffeine kick without the sugar or calories, simple coffee is the clear winner!*
#
# Relationship between sugar content, caloric value, and caffeine content in Starbucks beverages. The bubble chart plots sugar content (x-axis) against calorie content (y-axis), with bubble size representing caffeine content (mg). A key observation is that simple coffee beverages have the highest caffeine content while containing the least amount of sugar and calories. In contrast, many high-calorie, high-sugar beverages tend to have significantly lower caffeine levels. This finding underscores the nutritional trade-offs between different beverage choices.
